# %%
import pandas as pd
import matplotlib as plt
# %matplotlib inline

# %%
df = pd.read_csv('./data/ratings.csv')
movies = pd.read_csv('./data/movies.csv', index_col='movieId')

# %%
df['movieName'] = df['movieId'].map(movies['title'])

# %%
movies.head()
# Out:
#                                       title  \
# movieId
# 1                          Toy Story (1995)
# 2                            Jumanji (1995)
# 3                   Grumpier Old Men (1995)
# 4                  Waiting to Exhale (1995)
# 5        Father of the Bride Part II (1995)
#
#                                               genres
# movieId
# 1        Adventure|Animation|Children|Comedy|Fantasy
# 2                         Adventure|Children|Fantasy
# 3                                     Comedy|Romance
# 4                               Comedy|Drama|Romance
# 5                                             Comedy

# %%
df.head()
# Out:
#    userId  movieId  rating  timestamp                    movieName
# 0       1        1     4.0  964982703             Toy Story (1995)
# 1       1        3     4.0  964981247      Grumpier Old Men (1995)
# 2       1        6     4.0  964982224                  Heat (1995)
# 3       1       47     5.0  964983815  Seven (a.k.a. Se7en) (1995)
# 4       1       50     5.0  964982931   Usual Suspects, The (1995)

# %%
myUser = 42

pd.set_option('display.max_rows', None)
userdata = df[df['userId']==myUser].sort_values(by='rating')[:450]

# %%
userdata['movieYear'] = userdata['movieName'].apply(lambda x: x.split("(")[1].split(')')[0])

# %%
userdata
# Out:
#       userId  movieId  rating  timestamp  \
# 6296      42     4442     1.0  996216092
# 5891      42      141     1.0  996220726
# 6289      42     4333     1.0  996216379
# 6244      42     3694     1.0  996260963
# 6245      42     3695     1.0  996260241
# 6243      42     3693     1.0  996260841
# 6002      42     1094     1.0  996218443
# 6229      42     3438     1.0  996221269
# 6137      42     2492     1.0  996220790
# 6069      42     1689     1.0  996215883
# 5967      42      586     2.0  996219248
# 6044      42     1499     2.0  996256339
# 6252      42     3793     2.0  996212879
# 6253      42     3824     2.0  996217683
# 6256      42     3869     2.0  996221323
# 6257      42     3882     2.0  996215785
# 5958      42      520     2.0  996215153
# 6250      42     3764     2.0  996221356
# 6314      42     4686     2.0  996256937
# 6055      42     1617     2.0  996218105
# 5951      42      466     2.0  996221118
# 6262      42     3980     2.0  996216970
# ...

# %%
userdata['movieYear'] = pd.to_numeric(userdata['movieYear'], errors='coerce')

# %%
userdata[userdata['movieYear']<1980]
# Out:
#       userId  movieId  rating  timestamp  \
# 6426      43     1084     5.0  848994795
# 6425      43     1073     5.0  848994641
# 6409      43      594     5.0  848994152
# 6411      43      596     5.0  848994332
# 6415      43      616     5.0  848994349
#
#                                        movieName  movieYear
# 6426                     Bonnie and Clyde (1967)     1967.0
# 6425  Willy Wonka & the Chocolate Factory (1971)     1971.0
# 6409      Snow White and the Seven Dwarfs (1937)     1937.0
# 6411                            Pinocchio (1940)     1940.0
# 6415                      Aristocats, The (1970)     1970.0

# %%
len(df)
# Out:
# 9742

# %%
for item in genres_unique.values:
    print(movies[str(item[0])].value_counts() )
# Out:
# False    8479
# True     1263
# Name: Adventure, dtype: int64
# False    9131
# True      611
# Name: Animation, dtype: int64
# False    9078
# True      664
# Name: Children, dtype: int64
# False    5986
# True     3756
# Name: Comedy, dtype: int64
# False    8963
# True      779
# Name: Fantasy, dtype: int64
# False    8146
# True     1596
# Name: Romance, dtype: int64
# False    5381
# True     4361
# Name: Drama, dtype: int64
# False    7914
# True     1828
# Name: Action, dtype: int64
# False    8543
# True     1199
# Name: Crime, dtype: int64
# False    7848
# True     1894
# Name: Thriller, dtype: int64
# False    8764
# True      978
# Name: Horror, dtype: int64
# False    9169
# True      573
# Name: Mystery, dtype: int64
# False    8762
# True      980
# Name: Sci-Fi, dtype: int64
# False    9360
# True      382
# Name: War, dtype: int64
# False    9408
# True      334
# Name: Musical, dtype: int64
# False    9302
# True      440
# Name: Documentary, dtype: int64
# ...

# %%
df['genres'] = df['genres'].apply(lambda x: x.split("|"))

# %%
movies = df
genres_unique = pd.DataFrame(movies.genres.str.split('|').tolist()).stack().unique()
genres_unique = pd.DataFrame(genres_unique, columns=['genre']) # Format into DataFrame to store later
movies = movies.join(movies.genres.str.get_dummies().astype(bool))
movies.drop('genres', inplace=True, axis=1)

# %%
movies
# Out:
#       movieId                                      title  (no genres listed)  \
# 0           1                           Toy Story (1995)               False
# 1           2                             Jumanji (1995)               False
# 2           3                    Grumpier Old Men (1995)               False
# 3           4                   Waiting to Exhale (1995)               False
# 4           5         Father of the Bride Part II (1995)               False
# ...       ...                                        ...                 ...
# 9737   193581  Black Butler: Book of the Atlantic (2017)               False
# 9738   193583               No Game No Life: Zero (2017)               False
# 9739   193585                               Flint (2017)               False
# 9740   193587        Bungo Stray Dogs: Dead Apple (2018)               False
# 9741   193609        Andrew Dice Clay: Dice Rules (1991)               False
#
# ...

# %%
df['count_words'] = df['tag'].apply(lambda x: len(x.split()))

# %%
df['count_words'].value_counts()
# Out:
# 1     2282
# 2     1057
# 3      275
# 4       43
# 5       16
# 7        4
# 6        3
# 16       1
# 10       1
# 8        1
# Name: count_words, dtype: int64

# %%
 (2282 + 1057)/len(df)
# Out:
# 0.9065978821612816

# %%
df['timestamp'].plot.kde()

# %%
df['tag'].value_counts()
# Out:
# In Netflix queue       131
# atmospheric             36
# superhero               24
# thought-provoking       24
# surreal                 23
#                       ...
# slavery                  1
# Ben Kingsley             1
# heroic bloodshed         1
# out of order             1
# nonlinear storyline      1
# Name: tag, Length: 1589, dtype: int64

# %%
df[df['movieId']==356]
# Out:
#       userId  movieId                       tag   timestamp
# 1095     474      356                    shrimp  1137375519
# 1096     474      356                   Vietnam  1137375519
# 2782     533      356         bubba gump shrimp  1424753866
# 2783     533      356            lieutenant dan  1424753866
# 2784     533      356  stupid is as stupid does  1424753866
# 2890     567      356               bittersweet  1525287545
# 2891     567      356                 emotional  1525287537
# 2892     567      356              heartwarming  1525287541
# 2893     567      356                  touching  1525287539

# %%
mes = pd.read_csv('LLVisualFeatures13K_Log.csv')
mes.head()
# Out:
#    ML_Id        f1        f2        f3        f4        f5        f6        f7
# 0     89  0.440830  0.763504  0.784965  0.132239  0.176285  0.275521  0.707383
# 1     93  0.467434  0.657441  0.651940  0.024859  0.061322  0.226915  0.687485
# 2     94  0.700268  0.652688  0.653051  0.020993  0.050809  0.201239  0.498546
# 3     95  0.522593  0.720691  0.725353  0.017811  0.040945  0.240973  0.660679
# 4     96  0.782697  0.658655  0.648308  0.138313  0.172365  0.191381  0.353793
